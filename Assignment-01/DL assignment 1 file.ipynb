# %%
# Install TensorFlow, which includes the Keras deep learning API.
# !pip install -q tensorflow

# %%
# Import TensorFlow for deep learning operations.
import tensorflow as tf

# Import Keras from TensorFlow for accessing datasets and neural network tools.
from tensorflow import keras

# Import NumPy for numerical operations.
import numpy as np

# Import Matplotlib for data visualization.
import matplotlib.pyplot as plt

# Display the installed TensorFlow version.
print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.20.0
# Keras version: 3.13.2

# %%
# Load the MNIST handwritten digit dataset from Keras.
# The dataset is already divided into training and testing sets.
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Display the dimensions of the loaded datasets.
print("Training images:", X_train.shape)
print("Training labels:", y_train.shape)
print("Testing images:", X_test.shape)
print("Testing labels:", y_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training images: (60000, 28, 28)
# Training labels: (60000,)
# Testing images: (10000, 28, 28)
# Testing labels: (10000,)

# %%
# Display the data type and pixel value range before normalization.
print("Data type:", X_train.dtype)
print("Minimum pixel value:", X_train.min())
print("Maximum pixel value:", X_train.max())
# Out:
# Data type: uint8
# Minimum pixel value: 0
# Maximum pixel value: 255

# %%
# Display a few sample images from the training dataset.
plt.figure(figsize=(10, 4))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i], cmap="gray")
    plt.title(f"Label: {y_train[i]}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Normalize pixel values from the range 0-255 to the range 0-1.
# This helps the neural network train more efficiently.
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# Verify the new pixel value range.
print("Training data range:", X_train.min(), "to", X_train.max())
print("Testing data range:", X_test.min(), "to", X_test.max())
# Visualize the images after normalization to verify that
# normalization has preserved their visual appearance.
plt.figure(figsize=(10, 4))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i], cmap="gray")
    plt.title(f"Label: {y_train[i]}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Training data range: 0.0 to 1.0
# Testing data range: 0.0 to 1.0

# %%
# Display the final number of samples available for training and testing.
print("Number of training samples:", len(X_train))
print("Number of testing samples:", len(X_test))

# Display the shape of one input image.
print("Shape of one image:", X_train[0].shape)
# Out:
# Number of training samples: 60000
# Number of testing samples: 10000
# Shape of one image: (28, 28)
